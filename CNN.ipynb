# %%
# Load various imports
from datetime import datetime
from os import listdir
from os.path import isfile, join

import librosa
import librosa.display

import numpy as np
import pandas as pd

import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
mypath = "data/downsampled_clips"
filenames = [f for f in listdir(mypath) if (isfile(join(mypath, f)) and f.endswith('.wav'))]

# %%
p_id_in_file = [] # patient IDs corresponding to each file
for name in filenames:
    p_id_in_file.append(int(name[:3]))

p_id_in_file = np.array(p_id_in_file)

# %%
filepaths = [join(mypath, f) for f in filenames] # full paths of files

# %%
p_diag = pd.read_csv("data/Respiratory_Sound_Database/patient_diagnosis.csv",header=None) # patient diagnosis file

# %%
labels = np.array([p_diag[p_diag[0] == x][1].values[0] for x in p_id_in_file]) # labels for audio files

# %%
def add_noise(data):
    noise_value = 0.015 * np.random.uniform() * np.amax(data)
    data = data + noise_value * np.random.normal(size=data.shape[0])
    return data

# %%
def stretch_process(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate=0.8)

# %%
def pitch_process(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=pitch_factor)

# %%
def extract_process(data, sample_rate):
    output_result = np.array([])

    mean_zero = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    output_result = np.hstack((output_result, mean_zero))

    stft_out = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft_out, sr=sample_rate).T, axis=0)
    output_result = np.hstack((output_result, chroma_stft))

    mfcc_out = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate, n_mfcc=40).T, axis=0)
    output_result = np.hstack((output_result, mfcc_out))

    root_mean_out = np.mean(librosa.feature.rms(y=data).T, axis=0)
    output_result = np.hstack((output_result, root_mean_out))

    mel_spectogram = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    output_result = np.hstack((output_result, mel_spectogram))

    return output_result

# %%
def extract_features(file_name):
    """
    This function takes in the path for an audio file as a string, loads it,
    and extracts several audio features including mean values of MFCC, Zero Crossing Rate,
    Chromagram, Root Mean Square Energy, and Mel Spectrogram from the original and its augmented versions.
    """
    try:
        # Load the original audio file
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast', duration=42, offset=0.6)

        # Extract features from the original audio data
        extracted_features = extract_process(audio, sample_rate)
        result = np.array(extracted_features)

        # Add noise and extract features
        noise_out = add_noise(audio)
        output_2 = extract_process(noise_out, sample_rate)
        result = np.vstack((result, output_2))

        # Time-stretch and then pitch-shift before extracting features
        new_out = stretch_process(audio,0.8)
        stretch_pitch = pitch_process(new_out, sample_rate,pitch_factor=0.7)
        output_3 = extract_process(stretch_pitch, sample_rate)
        result = np.vstack((result, output_3))

    except Exception as e:
        print("Error encountered while parsing file: ", file_name)
        print("Error Details:", e)
        return None

    return result

# %%
features = []

# Iterate through each sound file and extract the features
for file_name in filepaths:
    data = extract_features(file_name)
    features.append(data)

print('Finished feature extraction from ', len(features), ' files')
features = np.array(features)
# Out:
# /Users/akshayraj/Documents/GT/s4/7641/RespiratorySoundProject/env/lib/python3.12/site-packages/librosa/core/pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# Finished feature extraction from  920  files

# %%
features.shape
# Out:
# (920, 3, 182)

# %%
# print class counts
unique_elements, counts_elements = np.unique(labels, return_counts=True)
print(np.asarray((unique_elements, counts_elements)))
# Out:
# [['Asthma' 'Bronchiectasis' 'Bronchiolitis' 'COPD' 'Healthy' 'LRTI'
#   'Pneumonia' 'URTI']
#  ['1' '16' '13' '793' '35' '2' '37' '23']]

# %%
# plot class counts
y_pos = np.arange(len(unique_elements))
plt.figure(figsize=(12,8))
plt.bar(unique_elements, counts_elements, align='center', alpha=0.5)
plt.xticks(y_pos, unique_elements)
plt.ylabel('Count')
plt.xlabel('Disease')
plt.title('Disease Count in Sound Files')
plt.show()

# %%
flattened_features = features.reshape(-1, 182)

# %%
augmented_labels = np.repeat(labels, 3)

# %%
augmented_features = np.reshape(features, (-1, 182))  # Flatten the feature sets
augmented_features.shape
mask = ~np.isin(augmented_labels, [])
augmented_features = augmented_features[mask]
augmented_labels = augmented_labels[mask]

# %%
le = LabelEncoder()
i_labels = le.fit_transform(augmented_labels)
oh_labels = to_categorical(i_labels)

# %%
oh_labels.shape
# Out:
# (2760, 8)

# %%
flattened_features.shape
# Out:
# (2760, 182)

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(flattened_features, oh_labels, stratify=oh_labels,
                                                    test_size=0.2, random_state = 42)

# %%
#SCALER & TRANSFORMATION
scaler_data = StandardScaler()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (2208, 182)
# (2208, 8)
# (552, 182)
# (552, 8)

# %%
x_train = scaler_data.fit_transform(x_train)
x_test = scaler_data.transform(x_test)

# %%
x_train = np.expand_dims(x_train,axis=2)
x_test = np.expand_dims(x_test,axis=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x_train = np.expand_dims(x_train,axis=2)
#       2 x_test = np.expand_dims(x_test,axis=2)
#
# NameError: name 'np' is not defined

# %%
from tensorflow.keras import layers, Sequential, regularizers, optimizers
from tensorflow.keras.layers import BatchNormalization, Add, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import Model, Input

def res_block(filter, stage):
    def layer_fn(X):
        X_copy = X

        X = layers.Conv1D(filters = filter, kernel_size = 5, strides = 1, padding = 'same', name = 'conv1' + str(stage))(X)
        X = BatchNormalization(name = 'bn1' + str(stage))(X)
        X = Activation('relu')(X)

        # Add skip connection
        X_copy = layers.Conv1D(filters = filter, kernel_size = 1, strides = 1, padding = 'same', name = 'skip' + str(stage))(X_copy)
        X = Add()([X, X_copy])
        X = Activation('relu')(X)

        return X
    return layer_fn

# Define the model
inputs = Input(shape=(x_train.shape[1], 1))

# Initial layer
x = layers.Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu')(inputs)
x = BatchNormalization()(x)
x = layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same')(x)

# Add residual blocks
for i in range(3):
    x = res_block(256, i+1)(x)
x = layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same')(x)

# Final layers
x = layers.Dropout(0.4)(x)
x = layers.Flatten()(x)
x = layers.Dense(units=32, activation='relu', kernel_regularizer=regularizers.l2(0.02))(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(units=num_labels, activation='softmax')(x)

Model = Model(inputs=inputs, outputs=outputs)

opt = optimizers.Adam(learning_rate=0.001)

# Compile the model
Model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
lr_reduction = ReduceLROnPlateau(monitor='val_loss', patience=5, verbose=1, factor=0.5)

# Fit the model
evConv1D_Model = Model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), callbacks=[early_stopping, lr_reduction])
# Out:
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.7742 - loss: 2.7919 - val_accuracy: 0.8623 - val_loss: 1.6400 - learning_rate: 0.0010
# Epoch 2/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.8414 - loss: 1.3221 - val_accuracy: 0.8623 - val_loss: 1.0730 - learning_rate: 0.0010
# Epoch 3/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8537 - loss: 0.9420 - val_accuracy: 0.8623 - val_loss: 0.8917 - learning_rate: 0.0010
# Epoch 4/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8555 - loss: 0.7955 - val_accuracy: 0.8605 - val_loss: 0.7828 - learning_rate: 0.0010
# Epoch 5/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8516 - loss: 0.7440 - val_accuracy: 0.8623 - val_loss: 0.7135 - learning_rate: 0.0010
# Epoch 6/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8607 - loss: 0.6629 - val_accuracy: 0.8623 - val_loss: 0.6408 - learning_rate: 0.0010
# Epoch 7/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8728 - loss: 0.6176 - val_accuracy: 0.8623 - val_loss: 0.5803 - learning_rate: 0.0010
# Epoch 8/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8577 - loss: 0.5542 - val_accuracy: 0.8623 - val_loss: 0.5513 - learning_rate: 0.0010
# Epoch 9/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - accuracy: 0.8596 - loss: 0.5030 - val_accuracy: 0.8623 - val_loss: 0.5477 - learning_rate: 0.0010
# Epoch 10/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.8615 - loss: 0.4615 - val_accuracy: 0.8623 - val_loss: 0.4836 - learning_rate: 0.0010
# Epoch 11/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8577 - loss: 0.4674 - val_accuracy: 0.8641 - val_loss: 0.4955 - learning_rate: 0.0010
# Epoch 12/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8568 - loss: 0.4715 - val_accuracy: 0.8641 - val_loss: 0.5034 - learning_rate: 0.0010
# Epoch 13/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8771 - loss: 0.4350 - val_accuracy: 0.8641 - val_loss: 0.5023 - learning_rate: 0.0010
# Epoch 14/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.8604 - loss: 0.4464 - val_accuracy: 0.8623 - val_loss: 0.5643 - learning_rate: 0.0010
# Epoch 15/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8753 - loss: 0.4347 - val_accuracy: 0.8551 - val_loss: 0.4774 - learning_rate: 0.0010
# Epoch 16/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8658 - loss: 0.4159 - val_accuracy: 0.8696 - val_loss: 0.5012 - learning_rate: 0.0010
# Epoch 17/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8712 - loss: 0.4347 - val_accuracy: 0.8732 - val_loss: 0.4661 - learning_rate: 0.0010
# Epoch 18/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8872 - loss: 0.4112 - val_accuracy: 0.8714 - val_loss: 0.4655 - learning_rate: 0.0010
# Epoch 19/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8701 - loss: 0.4320 - val_accuracy: 0.8768 - val_loss: 0.4951 - learning_rate: 0.0010
# Epoch 20/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.8953 - loss: 0.3694 - val_accuracy: 0.8877 - val_loss: 0.4499 - learning_rate: 0.0010
# Epoch 21/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9038 - loss: 0.3723 - val_accuracy: 0.8895 - val_loss: 0.4711 - learning_rate: 0.0010
# Epoch 22/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8987 - loss: 0.3840 - val_accuracy: 0.8859 - val_loss: 0.5331 - learning_rate: 0.0010
# Epoch 23/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8971 - loss: 0.4137 - val_accuracy: 0.8967 - val_loss: 0.5022 - learning_rate: 0.0010
# Epoch 24/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9075 - loss: 0.3495 - val_accuracy: 0.8822 - val_loss: 0.4913 - learning_rate: 0.0010
# Epoch 25/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8951 - loss: 0.3689
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.8952 - loss: 0.3689 - val_accuracy: 0.8877 - val_loss: 0.4768 - learning_rate: 0.0010
# Epoch 26/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9083 - loss: 0.3294 - val_accuracy: 0.8859 - val_loss: 0.5311 - learning_rate: 5.0000e-04
# Epoch 27/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.9159 - loss: 0.3123 - val_accuracy: 0.8986 - val_loss: 0.4495 - learning_rate: 5.0000e-04
# Epoch 28/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.9324 - loss: 0.2701 - val_accuracy: 0.8913 - val_loss: 0.4299 - learning_rate: 5.0000e-04
# Epoch 29/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.9323 - loss: 0.2681 - val_accuracy: 0.9004 - val_loss: 0.3972 - learning_rate: 5.0000e-04
# Epoch 30/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.9239 - loss: 0.2817 - val_accuracy: 0.8949 - val_loss: 0.4439 - learning_rate: 5.0000e-04
# Epoch 31/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.9401 - loss: 0.2569 - val_accuracy: 0.9004 - val_loss: 0.4329 - learning_rate: 5.0000e-04
# Epoch 32/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9369 - loss: 0.2501 - val_accuracy: 0.9022 - val_loss: 0.4105 - learning_rate: 5.0000e-04
# Epoch 33/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.9310 - loss: 0.2666 - val_accuracy: 0.9058 - val_loss: 0.4293 - learning_rate: 5.0000e-04
# Epoch 34/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.9364 - loss: 0.2477 - val_accuracy: 0.9094 - val_loss: 0.3735 - learning_rate: 5.0000e-04
# Epoch 35/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.9511 - loss: 0.2416 - val_accuracy: 0.9058 - val_loss: 0.4026 - learning_rate: 5.0000e-04
# Epoch 36/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9440 - loss: 0.2273 - val_accuracy: 0.9076 - val_loss: 0.5128 - learning_rate: 5.0000e-04
# Epoch 37/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.9518 - loss: 0.2287 - val_accuracy: 0.9076 - val_loss: 0.4289 - learning_rate: 5.0000e-04
# Epoch 38/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.9484 - loss: 0.2242 - val_accuracy: 0.9058 - val_loss: 0.4160 - learning_rate: 5.0000e-04
# Epoch 39/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9583 - loss: 0.2093
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - accuracy: 0.9583 - loss: 0.2093 - val_accuracy: 0.9149 - val_loss: 0.4436 - learning_rate: 5.0000e-04
# Epoch 40/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9613 - loss: 0.1923 - val_accuracy: 0.9149 - val_loss: 0.4296 - learning_rate: 2.5000e-04
# Epoch 41/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.9588 - loss: 0.1934 - val_accuracy: 0.9094 - val_loss: 0.4243 - learning_rate: 2.5000e-04
# Epoch 42/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.9645 - loss: 0.1715 - val_accuracy: 0.9167 - val_loss: 0.4056 - learning_rate: 2.5000e-04
# Epoch 43/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.9545 - loss: 0.1873 - val_accuracy: 0.9058 - val_loss: 0.4168 - learning_rate: 2.5000e-04
# Epoch 44/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9646 - loss: 0.1595
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.9646 - loss: 0.1596 - val_accuracy: 0.9185 - val_loss: 0.4425 - learning_rate: 2.5000e-04

# %%
Model_Results = Model.evaluate(x_train,y_train)
print("LOSS:  " + "%.4f" % Model_Results[0])
print("ACCURACY:  " + "%.4f" % Model_Results[1])
Model_Results = Model.evaluate(x_test,y_test)
print("LOSS:  " + "%.4f" % Model_Results[0])
print("ACCURACY:  " + "%.4f" % Model_Results[1])
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9913 - loss: 0.1102
# LOSS:  0.1042
# ACCURACY:  0.9937
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9073 - loss: 0.4816
# LOSS:  0.4425
# ACCURACY:  0.9185

# %%
# Plotting loss
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(evConv1D_Model.history['loss'], label='Training Loss')
plt.plot(evConv1D_Model.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Training and Validation Loss')

# Plotting accuracy
plt.subplot(1, 2, 2)
plt.plot(evConv1D_Model.history['accuracy'], label='Training Accuracy')
plt.plot(evConv1D_Model.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

plt.show()

# %%
# Getting the predictions
y_pred = Model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Generating the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

le.fit(np.union1d(y_true, y_pred_classes))
assert confusion_mtx.shape[0] == confusion_mtx.shape[1] == len(le.classes_)

# Displaying the confusion matrix
cm_display = ConfusionMatrixDisplay(confusion_mtx, display_labels=le.classes_).plot()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
from tensorflow.keras import layers, Sequential

num_labels = len(np.unique(labels)) 

Model2 = Sequential([
    layers.Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)),
    layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'),
    layers.Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'),
    layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'),
    layers.Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'),
    layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'),
    layers.Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'),
    layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'),
    layers.Conv1D(32, kernel_size=5, strides=1, padding='same', activation='relu'),
    layers.MaxPooling1D(pool_size=5, strides = 2, padding = 'same'),
    layers.Dropout(0.2),
    layers.Flatten(),
    layers.Dense(units=32, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(units=num_labels, activation='softmax')
])
Model2.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])
early_stop = tensorflow.keras.callbacks.EarlyStopping(monitor="loss",patience=3,mode="min")
evConv1D_Model2 = Model2.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/100
# /Users/akshayraj/Documents/GT/s4/7641/RespiratorySoundProject/env/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7441 - loss: 1.1259 - val_accuracy: 0.8623 - val_loss: 0.6064
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.8592 - loss: 0.7249 - val_accuracy: 0.8623 - val_loss: 0.6029
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.8632 - loss: 0.6849 - val_accuracy: 0.8623 - val_loss: 0.5804
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - accuracy: 0.8708 - loss: 0.6094 - val_accuracy: 0.8623 - val_loss: 0.5693
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.8675 - loss: 0.5851 - val_accuracy: 0.8623 - val_loss: 0.5395
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.8588 - loss: 0.5487 - val_accuracy: 0.8623 - val_loss: 0.5621
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.8657 - loss: 0.5149 - val_accuracy: 0.8623 - val_loss: 0.5144
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.8611 - loss: 0.5202 - val_accuracy: 0.8623 - val_loss: 0.5060
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.8666 - loss: 0.4603 - val_accuracy: 0.8587 - val_loss: 0.5051
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.8677 - loss: 0.4516 - val_accuracy: 0.8587 - val_loss: 0.5002
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8535 - loss: 0.4578 - val_accuracy: 0.8678 - val_loss: 0.4853
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8590 - loss: 0.4398 - val_accuracy: 0.8678 - val_loss: 0.4830
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8661 - loss: 0.4105 - val_accuracy: 0.8605 - val_loss: 0.5026
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.8528 - loss: 0.4325 - val_accuracy: 0.8659 - val_loss: 0.4706
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.8802 - loss: 0.3801 - val_accuracy: 0.8732 - val_loss: 0.4672
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.8701 - loss: 0.3746 - val_accuracy: 0.8569 - val_loss: 0.4914
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8740 - loss: 0.3674 - val_accuracy: 0.8641 - val_loss: 0.4687
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.8826 - loss: 0.3498 - val_accuracy: 0.8750 - val_loss: 0.4586
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8793 - loss: 0.3706 - val_accuracy: 0.8696 - val_loss: 0.5202
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.8791 - loss: 0.3228 - val_accuracy: 0.8605 - val_loss: 0.6696
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8758 - loss: 0.3780 - val_accuracy: 0.8732 - val_loss: 0.4132
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8946 - loss: 0.2899 - val_accuracy: 0.8768 - val_loss: 0.3838
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.8764 - loss: 0.3212 - val_accuracy: 0.8859 - val_loss: 0.4868
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9014 - loss: 0.2584 - val_accuracy: 0.8804 - val_loss: 0.4192
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9106 - loss: 0.2462 - val_accuracy: 0.8822 - val_loss: 0.5331
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9037 - loss: 0.2891 - val_accuracy: 0.8859 - val_loss: 0.4575
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9175 - loss: 0.2474 - val_accuracy: 0.8841 - val_loss: 0.4208
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.9281 - loss: 0.1962 - val_accuracy: 0.8913 - val_loss: 0.4773
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - accuracy: 0.9234 - loss: 0.2128 - val_accuracy: 0.8732 - val_loss: 0.4880
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9389 - loss: 0.1930 - val_accuracy: 0.8641 - val_loss: 0.4590
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9214 - loss: 0.2265 - val_accuracy: 0.8931 - val_loss: 0.4573
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step - accuracy: 0.9387 - loss: 0.1874 - val_accuracy: 0.8859 - val_loss: 0.4547
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9434 - loss: 0.1506 - val_accuracy: 0.8859 - val_loss: 0.4975
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9555 - loss: 0.1242 - val_accuracy: 0.8986 - val_loss: 0.5843
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.9327 - loss: 0.1990 - val_accuracy: 0.8986 - val_loss: 0.3705
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9507 - loss: 0.1606 - val_accuracy: 0.8768 - val_loss: 0.4003
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9419 - loss: 0.1631 - val_accuracy: 0.8895 - val_loss: 0.5254

# %%
Model_Results = Model2.evaluate(x_train,y_train)
print("LOSS:  " + "%.4f" % Model_Results[0])
print("ACCURACY:  " + "%.4f" % Model_Results[1])
Model_Results = Model2.evaluate(x_test,y_test)
print("LOSS:  " + "%.4f" % Model_Results[0])
print("ACCURACY:  " + "%.4f" % Model_Results[1])
# Out:
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9583 - loss: 0.1364
# LOSS:  0.1319
# ACCURACY:  0.9574
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8877 - loss: 0.5592
# LOSS:  0.5254
# ACCURACY:  0.8895

# %% [markdown]
# Plotting Train and Validation Loss & Accuracy:

# %%
# Plotting loss
plt.figure(figsize=(14, 5))
plt.subplot(1, 2, 1)
plt.plot(evConv1D_Model2.history['loss'], label='Training Loss')
plt.plot(evConv1D_Model2.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Training and Validation Loss')

# Plotting accuracy
plt.subplot(1, 2, 2)
plt.plot(evConv1D_Model2.history['accuracy'], label='Training Accuracy')
plt.plot(evConv1D_Model2.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

plt.show()

# %% [markdown]
# Confusion Matrix:

# %%
# Getting the predictions
y_pred = Model2.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

# Generating the confusion matrix
confusion_mtx = confusion_matrix(y_true, y_pred_classes)

le.fit(np.union1d(y_true, y_pred_classes))
assert confusion_mtx.shape[0] == confusion_mtx.shape[1] == len(le.classes_)

# Displaying the confusion matrix
cm_display = ConfusionMatrixDisplay(confusion_mtx, display_labels=le.classes_).plot()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
